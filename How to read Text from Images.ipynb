# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import cv2

# %%
img = cv2.imread('img158.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
cv2.imshow('Sample image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# ——————— = " -
#
#
#
# IRDA ot ine eg No.1 ed 1712007 | CN: UELOOOMEZOOPPLIBOSAS | UN: S8G-0.P1257402.1-12 SBIGeneral
# PRIVATE CAR/TWO WHEELER INSURANCE POLICY. = UNSEEN
# {8 see win abigeneralifdownoad Hee Seiten ye eg
# Proposal Form | Pace uty
# The queries sates below are ruenur equrement io be Renished By a Proposer Theis may Seek mae elon 3 dese or undertng purboee i =
# ee Prpastor: New || Renee | Rot Owe ‘Und Extranet aueaneuieras
#
# romeo PED EF MUMAL SOAe moe (GVO TGST | em Te20c
# doe = | AVN TSF « seat 3 sea gg Rite’ (\2SGS CF) fgren Rep |
# foal | isqi ae beet a eco No, Recootdae 0) || 022/021
#
#
#
# Siam USGA soe West Beryl vee ©1234 |
# feces Soc unan [al [Sos osmnon [BT GESD A) | cexomersemen — sowey (7 Bxes || Capontatotng (me
# yeu eg rst Wn SB Gnas De se ow ter D/P une” "2 BESLF RY T
# WET) ww (ABODE T KiMAL peel T Td Lh Teer
# Goer isco oweateen “OL O\ VAG come \OPYSCERF |
# mato Ne. eiB anal Le Lefolrs wows YS 208 |
# cccounatenses (1 2&4 SE
# 09 Pease OL ol. rad i cums PUIG TT
# fea nie BEE wot CCTGE toon NO RTH |
# wear KOLA TA Som KR I
# om (WESIT TT TBEN GATT Sa]
# Conente Ws te) GSTNISON
#
# Peetotnonnccton [OTT Tod) me ON [20 RD: smewte (OL Iit 201204) rom [BO
#
# Proves Wer Mio Food 102 LBD wOl O29 PBI) ead Sel Di] Betyeaee” (2G) amon [429
#
# ronda pean sey it [
# Kole
#
#
#
#
#
#
#
# ene ad I an WEBESESGES
# = aes Dowie (210) orang aes 10] Penn [Ue [Pam oe 1 eee
# onetennn L}LO a5 Bri2ysuy RE KOLKOTA fe, DURKAP D
# : i fa
# “Wehva" Su. cca ie ee Ch) ee cee
#
# ‘rice rs Onearesvabe A fue-Grcreal | Tri vita Rs | Sara aia S| ene) Lok Re Taal OV
# sects, | Matson (ro wees) x ontedyrartct)
#
# See Se Se eee
#
#
#
#
#
# A eget aby to Pa Driver No ot Pesons PA To Oweus Onver(Pase gue deta of Norinwton) *) Pato unnemad Passenger Sum ns +
#
# Nerina dameiere — (GLI KUMAR SIRO PE BT | oe Oia Tel ale) mim [7
#
# (eam TS KUMAe KUM Ae Sienorwoe Sp~
#
# NY oercnonRanevsenst PCO), Cr Gane Pacey) | Er a ACh) awsome
#
# {7 Prt tombe pete Oyo) Area orate care) Al aster Oy
#
# ‘xsl een Baa PCa Rs ovr tegen Ca) enn Nace at OR
#
# for me nnn PB PC a a pen
#
# hep Ca Co rae Oc re) sed ase / aD Co rence rnc)
#
# omer PAL aa OIL TT TT il
#
# woo [TS5O0 1 | 1 [roll PT taco (FORT FRULIO =
# Iegrane monet orb pp tei nr ttre dr ra me PEED DRC nee De a
# feet Tone ‘Saez
# tetcecmy soe = San eT =
# Crees mores bata a t 1 Can yatta rs
# “ewan yx bt on ar  eteeger btrtoomegS et = wo
#
#
#
#
#
#
#
# i
# i
#
# [PJ saimaceani rs
# [_aereamre
#
# ‘nase Ps
# [Si sitmncenete rs

# %%
## Detecting the Characters

hImg,wImg,_ =img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    ##print(b)
    b = boxes.split(' ')   
    ##print(b)
    x,y,w,h = int(b[1]),int(b[2]),int(b[3]),int(b[4])
    cv2.rectangle(img,(x,hImg-y),(w,hImg-h),(0,255,0),1)
    
cv2.imshow('resize image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#detecting only digits
hImg, wImg,_ = img.shape
 conf = r'--oem 3 --psm 6 outputbase digits'
 boxes = pytesseract.image_to_boxes(img,config=conf)
 for b in boxes.splitlines():
    print(b)
     b = b.split(' ')
    print(b)
     x, y, w, h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
    cv2.rectangle(img, (x,hImg- y), (w,hImg- h), (50, 50, 255), 2)
     cv2.putText(img,b[0],(x,hImg- y+25),cv2.FONT_HERSHEY_SIMPLEX,1,(50,50,255),2)

# %%
img2 = cv2.imread('img159.jpg')
cv2.imshow('Sample',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text2 = pytesseract.image_to_string(img2)
print(text2)
# Out:
#  targiacesh Bhutan Malone: Nepal || Pakistan [| seanka
# tomate Associ fda Webrstp No, 5 UZ USLFY TV] 24 LF Duettory Oi} QO i 1
#
# $F tomer aevcs 97 ects ere Bi Hundcapet/ Meaty cand Pon At oprewca curse
# {Larne gay sy Saray Coe sy Rt eee
#
# bere nts Te Pay Popeye coe i 2 rs a 75 ts ta Ca)
# [ — —— eng ton — ——
#
# Cow trees pares woes ty
# LA ac. Rates. Sees Lge Cr Covers of cessor ut try ousting o at ACT ee)
# ee rer
#
# | Person Act Coroners compro sumiedct Re. 5 00 00
#
# 1 Gacamadir Acne teaner sherawat oad cme apap ro smb caper own td etc gcse,
# UoeamedOecapst Posengers
#
# Fa Senaesow pent 0.00: ramet Re. 6.00pm wens 200,00 pr pnt iv a. The mane pers ec rhe pest
#
# I te Ses reps cay en
# ~ ( Pamet evctnsret (CF Rena te Ply Coy ws — EE spas
#
#
#
#
#
# [Gmamecrnaet (tuo PRpuemrincttciienem fete
# cee = Be comets ee oP nawcas
#
# A ecnor [ey ing ene F- Baewen 0
#
# Ira AT ORDO WERNER nee ee ee
#
# Che ya resect PBs ei fr)
# 7 ws0.osa manners [) costinsine seston ie [Lxany rm Ray [HCAS eps Srees it
# [YY ita erases rae i
#
# "OO eens a
#
#
#
#
#
# ST TD eo)
#
#
#
#
#
#
#
#
# PAYMENT OETALS i CHEOUE DEAI/OREDIT CARD
# {at Ro Ao ee SE (ssn meee)
# ene a ea Chas py on et“ Geel ees Conga no
#
# tenmennror |} 9 [ATU IST Cet snort B16 10 © (ol GON 2131U5} pe [Oyo [Wor 21
#
# skies Se role TTT al TE} mmm Sigicl TT
#
# Back Account No. ES: it I | FSC Coe ©00).239 204901 2
#
#
#
# {Qtetrtncefrn ht a esre ee wb pad arba ses cn pemions awebe wb aso of octet eae oan Kc Poona Morey Lander
# £25200 lsc it Conga has recall Soares wash ote ants Twas Compan haste apbcecave nurscecomncireasion mantener,
# caper Sat eyo re gong erst y)
#
# aoa ni Nona Nene. ese techy Cory
#
# ‘ipectCrsnen Con Gor hn Govrres ‘Bimoses
#
#
#
# {eb cca tt tN ated me caren al CLA sane neg py prony ky ec ht eae Ns acd were a
#
# ‘ane cre Pty nap Sent te yl dae
# ‘eet creat ete y ela es re me rc Pa ey i eb Pal on wih ry
#
# som
# resus ioe rbot Therap bt ear wat ra ae reat a 2 wt ry
# ae Gee png tt De ono pester Sea DOP SemanonteaMoN eats MSO eee se
#
# sur ne Canary se vce open he Campane eet any ms apes. ete on cour onceg ey emp by
# cg ay rent echo mya amano bce pears eee Se
# Fy sae mete atrawenarcezanmtont mesh Greer
# fal 3 Ou dm a asc ad yf 8 Gana ast comes sere et wesraeu on
# feces suey bd cata a esa Se TSS a en
#
#
#
# {ten ave mu conse SG tka dacaaaande. cee tra’ gry son Vc he ene orl a rte a ie ns Pepa ee,
#
# Meeeta tow sn attra tacoma manta saasag Ube pepea ae ent eee ee i oan fa
#
# (ee order ose nr Coven sarg mires enw Sie Bc Gras rs pete pups eg eves ees py fe ek Gog nue sha usecase
# pened aoe
#
# uovnrta oontos nt : oD ores
# ow 012 Of 4412) Puce [ol LR AT: At i J Sipaare # Peso
# epic wre Paps sero henge a wich ec r rhe Peon has hed mea ep)
#
# (oe: The ben stb waressey someone or tan he army ie Carey)
#
# {cay ae rotted ryan cote Prog Tr have be eat ada mesa Ve ae ay nesta em. We eer xy be pts
# ‘rapa hare oe ecards rsa onde nek x
#
# wears coca aes ements
# oe Co Se
# Enth aun naan e e e
#
# a ce eae
#
# ome (QTOTETTATGTO] rex [QOL K ATA]  soumeytene emacs steer
#
# ay Uri | OA eda eg, ‘oi ueesoomoar:
# of ae an ta a es y 0 Garr trace Ca (a un Sore
#
#
#
#
#
#
#
# = “o-
#
#
#
# ‘Sel oweal
